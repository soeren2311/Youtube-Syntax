# %% [markdown]
# <a href="https://colab.research.google.com/github/soeren2311/Youtube-Syntax/blob/main/Matplotlib_Video_(Teil_1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
alter_x = [20, 23, 25, 28, 29, 35, 41, 47, 51, 58, 64, 67, 68, 70, 71, 73]
eink_L1 = [800, 920, 1260, 1210, 1980, 2890, 2650, 4000, 4100, 4520, 4480, 3100, 
          2320, 1730, 1400, 1380] 

eink_L2 = [1200, 1320, 1560, 1710, 1980, 3560, 3340, 3820, 4850, 4360, 4200, 
           3800, 2720, 2900, 2600, 2920]

plot_1 = plt.figure(figsize=(15, 10))
plt.plot(alter_x, eink_L1, color='r', linestyle="-.", marker="o", label="Deutschland")
plt.plot(alter_x, eink_L2, color='k', marker="+", label="Schweden")
plt.xlabel('Alter in Jahren')
plt.ylabel('Einkommen in €')
plt.title('Zusammenhang von Alter und Einkommen')
plt.grid(True)
plt.legend()
